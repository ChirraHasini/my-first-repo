# %% [markdown]
# Hardware is the physical equipment you can touch,while software is the set of insturctions that tells that equipment what to do.
# Hardware examples:keyboard,CPU,Hard Disk Drives,Monitors etc.
# Software examples:windows,linux
